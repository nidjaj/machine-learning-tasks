# %% [markdown]
# <a href="https://colab.research.google.com/github/nidjaj/machine-learning-tasks/blob/master/problem3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("student.csv")

plt.pie(df.iloc[0:,1],labels=df.iloc[0:,0],explode=(0.1,0,0,0),autopct="%1.1f%%",shadow=True)
plt.legend()
plt.show()
